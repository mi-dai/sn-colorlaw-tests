# %% [markdown]
# # SN light curve fitting

# %% [markdown]
# This exploratory notebook tries to use tape to fit SN Ia light curves using a SALT3 model from SNCosmo

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sncosmo
from tape import Ensemble
from tape.utils import ColumnMapper
import pandas as pd
import dask.dataframe as dd
from snutils import PanPlusUtils
import os
import glob
import matplotlib.pyplot as plt
import numpy as np
from datautils import fit_salt2,fit_salt2_pp

# %%
ens = Ensemble(client=False)

# %%
ppsn = PanPlusUtils()
fit_lcparams = ppsn.fit_lcparams

# %%
kcorfiles = glob.glob(os.path.expandvars("data/salt3/kcor/*.input"))
dflist = []
for f in kcorfiles:
    df = ppsn._read_snana_kcor_input(f,rename_bands=True)
    dflist.append(df)
filtmap = pd.concat(dflist)
def replace_str(row):
    for col in ['filtname','survey']:
        row[col] = row[col].replace('CSPDR2','CSPDR3')
    return row
filtmap = filtmap.apply(replace_str,axis=1)
filtmap = filtmap.drop_duplicates()
filtmap.head()
# Out:
#            filtname filtstr            filtfile  refmag  survey magsys  \
# 0  CSPDR3-Bessell-U       U  sux-shifted.dat_5A   9.724  CSPDR3   BD17
# 1  CSPDR3-Bessell-B       B   sb-shifted.dat_5A   9.907  CSPDR3   BD17
# 2  CSPDR3-Bessell-V       V   sv-shifted.dat_5A   9.464  CSPDR3   BD17
# 3  CSPDR3-Bessell-R       R   sr-shifted.dat_5A   9.166  CSPDR3   BD17
# 4  CSPDR3-Bessell-I       I   si-shifted.dat_5A   8.846  CSPDR3   BD17
#
#                                           filtpath
# 0  $SNDATA_ROOT/filters/PS1/Pantheon/SNLS3-Landolt
# 1  $SNDATA_ROOT/filters/PS1/Pantheon/SNLS3-Landolt
# 2  $SNDATA_ROOT/filters/PS1/Pantheon/SNLS3-Landolt
# 3  $SNDATA_ROOT/filters/PS1/Pantheon/SNLS3-Landolt
# 4  $SNDATA_ROOT/filters/PS1/Pantheon/SNLS3-Landolt

# %%
ppsn.register_bands_for_sncosmo(filtmap=filtmap)

# %%
ens = Ensemble()

# %%
src,obj = ppsn.get_sn_data('data/salt3/SALT3TRAIN_PanPlus/SALT3TRAIN_K21_Fou*/',rename_bands=True,rename_bands_thres=100)

# %%
src.head()
# Out:
#   VARLIST:          MJD                   FLT FIELD   FLUXCAL  FLUXCALERR  \
# 0     OBS:  57215.27501  Foundation_DR1-PS1-g  VOID  9615.449     202.204
# 1     OBS:  57221.27233  Foundation_DR1-PS1-g  VOID  9623.916     234.360
# 2     OBS:  57227.27655  Foundation_DR1-PS1-g  VOID  6916.386     189.081
# 3     OBS:  57233.27105  Foundation_DR1-PS1-g  VOID  3707.125     176.033
# 4     OBS:  57242.27707  Foundation_DR1-PS1-g  VOID  1590.206      97.227
#
#       MAG  MAGERR   PSF         SNID FLT_str
# 0  17.543   0.023  2.39  ASASSN-15mg
# 1  17.542   0.026  3.21  ASASSN-15mg
# 2  17.900   0.030  1.86  ASASSN-15mg
# 3  18.577   0.051  2.08  ASASSN-15mg
# 4  19.496   0.066  2.08  ASASSN-15mg

# %%
obj.head()
# Out:
#        SURVEY  SNTYPE         SNID          RA          DEC  MWEBV FILTERS  \
# 0  FOUNDATION     1.0  ASASSN-15mg  233.094056     41.85038  0.028    griz
# 0  FOUNDATION     1.0  ASASSN-17bs  268.025540    21.566021  0.076    griz
# 0  FOUNDATION     1.0  ASASSN-16ay  108.059415     7.239544  0.059    griz
# 0  FOUNDATION     1.0     AT2017lm   45.384899  -15.0159632  0.059    griz
# 0  FOUNDATION     1.0  MASTEROTJ15  229.196787    28.628617  0.024    griz
#
#    SEARCH_PEAKMJD  HOSTGAL_LOGMASS_err  HOSTGAL_LOGMASS  PIXSIZE  \
# 0     57221.27273                0.029           10.134     0.25
# 0     57794.60710                0.012           10.735     0.25
# 0     57418.42390                0.001           10.615     0.25
# 0     57776.23572                0.013           10.110     0.25
# 0     57585.29938                0.100            6.000     0.25
#
#    REDSHIFT_HELIO_err  REDSHIFT_HELIO  REDSHIFT_CMB_err  REDSHIFT_CMB  \
# 0            0.000012        0.042778          0.000012      0.043071
# 0            0.000020        0.020397          0.000020      0.020135
# 0            0.000013        0.028343          0.000013      0.028953
# 0            0.000064        0.030636          0.000064      0.030023
# 0            0.000015        0.056436          0.000015      0.056904
#
#    VPEC_err       VPEC         SURVEY2
# 0     250.0  -289.7960  Foundation_DR1
# 0     250.0  -125.0670  Foundation_DR1
# 0     250.0  -124.5780  Foundation_DR1
# 0     250.0   -83.3033  Foundation_DR1
# 0     250.0    24.7887  Foundation_DR1

# %%
col_map = ColumnMapper(id_col="SNID",
    time_col="MJD",
    flux_col="FLUXCAL",
    err_col="FLUXCALERR",
    band_col="FLT")

# %% [markdown]
# #### try using pandas df first

# %%
ens.from_pandas(src,obj,column_mapper=col_map,npartitions=1,sync_tables=False)

# %%
# ens.query("SNID == 'ASASSN-15mg'","object")

# %%
obj = ens.compute("object")
obj
# Out:
#                  SURVEY  SNTYPE          RA          DEC  MWEBV FILTERS  \
# SNID
# 2016W        FOUNDATION     1.0   37.665487   42.2359685  0.060    griz
# ASASSN-15bc  FOUNDATION     1.0   61.560987   -8.8856098  0.037    griz
# ASASSN-15fs  FOUNDATION     1.0  284.669923   43.4688739  0.077    griz
# ASASSN-15go  FOUNDATION     1.0   92.876886  -16.4841129  0.137    griz
# ASASSN-15hg  FOUNDATION     1.0  148.452399    9.1938997  0.042    griz
# ...                 ...     ...         ...          ...    ...     ...
# SN2017coa    FOUNDATION     1.0  132.480332   56.0990451  0.056    griz
# SN2017cpu    FOUNDATION     1.0  211.968898    9.6420343  0.024    griz
# SN2017hn     FOUNDATION     1.0  196.914215    6.3376016  0.028    griz
# SN2017jl     FOUNDATION     1.0   14.382880   30.1852335  0.063    griz
# SN2017mf     FOUNDATION     1.0  214.129418   39.5863529  0.009    griz
#
#              SEARCH_PEAKMJD  HOSTGAL_LOGMASS_err  HOSTGAL_LOGMASS  PIXSIZE  \
# SNID
# 2016W           57420.27212                0.002           11.388     0.25
# ASASSN-15bc     57046.21469                0.011           10.187     0.25
# ASASSN-15fs     57110.63102                0.001           10.379     0.25
# ASASSN-15go     57124.25913                0.027           10.072     0.25
# ASASSN-15hg     57134.24798                0.006           10.507     0.25
# ...                     ...                  ...              ...      ...
# SN2017coa       57846.35159                0.030            7.575     0.25
# SN2017cpu       57847.49753                0.001           10.709     0.25
# SN2017hn        57766.64586                0.001           10.577     0.25
# SN2017jl        57783.22590                0.008            9.155     0.25
# SN2017mf        57777.66039                0.013           11.077     0.25
#
#              REDSHIFT_HELIO_err  REDSHIFT_HELIO  REDSHIFT_CMB_err  \
# SNID
# 2016W                  0.000067        0.019253          0.000067
# ASASSN-15bc            0.000097        0.036715          0.000097
# ASASSN-15fs            0.000047        0.029020          0.000047
# ASASSN-15go            0.000150        0.018923          0.000150
# ASASSN-15hg            0.000010        0.029917          0.000010
# ...                         ...             ...               ...
# SN2017coa              0.003000        0.040000          0.003000
# SN2017cpu              0.000010        0.054405          0.000010
# SN2017hn               0.000008        0.023850          0.000008
# SN2017jl               0.000444        0.016331          0.000444
# SN2017mf               0.000009        0.025612          0.000009
#
#              REDSHIFT_CMB  VPEC_err       VPEC         SURVEY2  nobs_total
# SNID
# 2016W            0.018555     250.0  -411.4148  Foundation_DR1         NaN
# ASASSN-15bc      0.036388     250.0  -330.3994  Foundation_DR1         NaN
# ASASSN-15fs      0.028501     250.0  -196.2154  Foundation_DR1         NaN
# ASASSN-15go      0.019277     250.0   107.1331  Foundation_DR1         NaN
# ASASSN-15hg      0.031068     250.0  -105.0075  Foundation_DR1         NaN
# ...                   ...       ...        ...             ...         ...
# SN2017coa        0.040450     250.0  -143.5611  Foundation_DR1         NaN
# SN2017cpu        0.055292     250.0    78.2932  Foundation_DR1         NaN
# SN2017hn         0.024923     250.0  -189.3225  Foundation_DR1         NaN
# SN2017jl         0.015293     250.0    11.8215  Foundation_DR1         NaN
# SN2017mf         0.026183     250.0    59.0114  Foundation_DR1         NaN
#
# [153 rows x 18 columns]

# %%
src = ens.compute("source")
src
# Out:
#          VARLIST:          MJD                   FLT FIELD    FLUXCAL  \
# SNID
# 2016W        OBS:  57410.29056  Foundation_DR1-PS1-g  VOID  23285.733
# 2016W        OBS:  57415.25541  Foundation_DR1-PS1-g  VOID  41770.651
# 2016W        OBS:  57420.27171  Foundation_DR1-PS1-g  VOID  40402.139
# 2016W        OBS:  57427.25693  Foundation_DR1-PS1-g  VOID  28340.979
# 2016W        OBS:  57434.23639  Foundation_DR1-PS1-g  VOID  13181.220
# ...           ...          ...                   ...   ...        ...
# SN2017mf     OBS:  57783.63259  Foundation_DR1-PS1-z  VOID  17049.060
# SN2017mf     OBS:  57789.64288  Foundation_DR1-PS1-z  VOID  12785.610
# SN2017mf     OBS:  57798.63098  Foundation_DR1-PS1-z  VOID  12396.736
# SN2017mf     OBS:  57808.58059  Foundation_DR1-PS1-z  VOID  10737.039
# SN2017mf     OBS:  57825.57363  Foundation_DR1-PS1-z  VOID   3573.894
#
#           FLUXCALERR     MAG  MAGERR   PSF FLT_str
# SNID
# 2016W        455.303  16.582   0.021  2.66
# 2016W        633.777  15.948   0.016  2.01
# 2016W        619.810  15.984   0.017  2.53
# 2016W        452.276  16.369   0.017  2.59
# 2016W        267.003  17.200   0.022  1.93
# ...              ...     ...     ...   ...     ...
# SN2017mf     321.870  16.921   0.020  2.26
# SN2017mf     242.814  17.233   0.021  1.79
# SN2017mf     252.615  17.267   0.022  1.52
# SN2017mf     237.274  17.423   0.024  1.37
# SN2017mf     180.337  18.617   0.055  1.89
#
# [4852 rows x 10 columns]

# %%
a2 = src.FLT.unique()

# %%
np.sort(np.array(a2))
# Out:
# array(['Foundation_DR1-PS1-g', 'Foundation_DR1-PS1-i',
#        'Foundation_DR1-PS1-r', 'Foundation_DR1-PS1-z'], dtype=object)

# %%
a1 = filtmap.filtname.unique()
# print(np.sort(a1))

# %%
set(a2)-set(a1)
# Out:
# set()

# %% [markdown]
# #### testing the function without using tape

# %%
data = ens.compute(table="source").reset_index()
meta = ens.compute(table="object").reset_index()
res = fit_lcparams(data,meta,filtmap=filtmap)
# Out:
# Base model info:
# <Model at 0x29fa52cb0>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  2016W z= 0.019253 zsource= MetaData mwebv= 0.06
# 1 fitting  ASASSN-15bc z= 0.036715 zsource= MetaData mwebv= 0.037
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 2 fitting  ASASSN-15fs z= 0.02902 zsource= MetaData mwebv= 0.077
# 3 fitting  ASASSN-15go z= 0.018923 zsource= MetaData mwebv= 0.137
# 4 fitting  ASASSN-15hg z= 0.029917 zsource= MetaData mwebv= 0.042
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 5 fitting  ASASSN-15jl z= 0.034682 zsource= MetaData mwebv= 0.014
# 6 fitting  ASASSN-15kx z= 0.018019 zsource= MetaData mwebv= 0.141
# 7 fitting  ASASSN-15lg z= 0.020151 zsource= MetaData mwebv= 0.027
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 8 fitting  ASASSN-15mf z= 0.026039 zsource= MetaData mwebv= 0.032
# 9 fitting  ASASSN-15mg z= 0.042778 zsource= MetaData mwebv= 0.028
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 10 fitting  ASASSN-15np z= 0.037683 zsource= MetaData mwebv= 0.026
# 11 fitting  ASASSN-15nq z= 0.03036 zsource= MetaData mwebv= 0.04
# 12 fitting  ASASSN-15nr z= 0.023206 zsource= MetaData mwebv= 0.112
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 13 fitting  ASASSN-15od z= 0.017603 zsource= MetaData mwebv= 0.026
# 14 fitting  ASASSN-15oh z= 0.016835 zsource= MetaData mwebv= 0.128
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 15 fitting  ASASSN-15pm z= 0.048784 zsource= MetaData mwebv= 0.028
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 16 fitting  ASASSN-15pn z= 0.038358 zsource= MetaData mwebv= 0.081
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 17 fitting  ASASSN-15pr z= 0.033093 zsource= MetaData mwebv= 0.029
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 18 fitting  ASASSN-15so z= 0.007022 zsource= MetaData mwebv= 0.013
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 19 fitting  ASASSN-15ss z= 0.035558 zsource= MetaData mwebv= 0.199
# 20 fitting  ASASSN-15tg z= 0.035615 zsource= MetaData mwebv= 0.025
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 21 fitting  ASASSN-15ti z= 0.01732 zsource= MetaData mwebv= 0.129
# 22 fitting  ASASSN-15tz z= 0.022862 zsource= MetaData mwebv= 0.141
# 23 fitting  ASASSN-15uv z= 0.020279 zsource= MetaData mwebv= 0.029
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 24 fitting  ASASSN-16ad z= 0.016131 zsource= MetaData mwebv= 0.042
# 25 fitting  ASASSN-16aj z= 0.030745 zsource= MetaData mwebv= 0.028
# 26 fitting  ASASSN-16ay z= 0.028343 zsource= MetaData mwebv= 0.059
# 27 fitting  ASASSN-16bq z= 0.024935 zsource= MetaData mwebv= 0.033
# 28 fitting  ASASSN-16br z= 0.02852 zsource= MetaData mwebv= 0.138
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 29 fitting  ASASSN-16ch z= 0.026683 zsource= MetaData mwebv= 0.021
# 30 fitting  ASASSN-16cs z= 0.018019 zsource= MetaData mwebv= 0.114
# 31 fitting  ASASSN-16ct z= 0.04191 zsource= MetaData mwebv= 0.046
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 32 fitting  ASASSN-16db z= 0.034864 zsource= MetaData mwebv= 0.023
# 33 fitting  ASASSN-16dn z= 0.01285 zsource= MetaData mwebv= 0.033
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 34 fitting  ASASSN-16dw z= 0.034657 zsource= MetaData mwebv= 0.046
# 35 fitting  ASASSN-16fo z= 0.0289 zsource= MetaData mwebv= 0.027
# 36 fitting  ASASSN-16fs z= 0.029205 zsource= MetaData mwebv= 0.028
# 37 fitting  ASASSN-16hr z= 0.030858 zsource= MetaData mwebv= 0.105
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 38 fitting  ASASSN-16hz z= 0.025308 zsource= MetaData mwebv= 0.031
# 39 fitting  ASASSN-16ip z= 0.017008 zsource= MetaData mwebv= 0.017
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 40 fitting  ASASSN-16jf z= 0.011441 zsource= MetaData mwebv= 0.02
# 41 fitting  ASASSN-16la z= 0.015054 zsource= MetaData mwebv= 0.18
# 42 fitting  ASASSN-16lg z= 0.021171 zsource= MetaData mwebv= 0.068
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 43 fitting  ASASSN-16oz z= 0.031 zsource= MetaData mwebv= 0.047
# 44 fitting  ASASSN-17aj z= 0.021275 zsource= MetaData mwebv= 0.036
# 45 fitting  ASASSN-17at z= 0.02537 zsource= MetaData mwebv= 0.024
# 46 fitting  ASASSN-17bs z= 0.020397 zsource= MetaData mwebv= 0.076
# 47 fitting  ASASSN-17co z= 0.018259 zsource= MetaData mwebv= 0.091
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 48 fitting  ASASSN-17eb z= 0.049239 zsource= MetaData mwebv= 0.035
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 49 fitting  AT2016aj z= 0.067406 zsource= MetaData mwebv= 0.041
# 50 fitting  AT2016bln z= 0.023303 zsource= MetaData mwebv= 0.025
# 51 fitting  AT2016cor z= 0.049543 zsource= MetaData mwebv= 0.027
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 52 fitting  AT2016cvv z= 0.044571 zsource= MetaData mwebv= 0.089
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 53 fitting  AT2016cvw z= 0.038877 zsource= MetaData mwebv= 0.068
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 54 fitting  AT2016cyt z= 0.03074 zsource= MetaData mwebv= 0.072
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 55 fitting  AT2016eoa z= 0.021087 zsource= MetaData mwebv= 0.061
# 56 fitting  AT2016ews z= 0.045553 zsource= MetaData mwebv= 0.038
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 57 fitting  AT2016gmg z= 0.049437 zsource= MetaData mwebv= 0.118
# 58 fitting  AT2016gsu z= 0.076419 zsource= MetaData mwebv= 0.041
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 59 fitting  AT2016hns z= 0.03817 zsource= MetaData mwebv= 0.063
# 60 fitting  AT2016htm z= 0.043313 zsource= MetaData mwebv= 0.015
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 61 fitting  AT2016htn z= 0.053117 zsource= MetaData mwebv= 0.023
# 62 fitting  AT2017cfb z= 0.022904 zsource= MetaData mwebv= 0.028
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 63 fitting  AT2017cfc z= 0.024027 zsource= MetaData mwebv= 0.04
# 64 fitting  AT2017lm z= 0.030636 zsource= MetaData mwebv= 0.059
# 65 fitting  AT2017ns z= 0.028766 zsource= MetaData mwebv= 0.094
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 66 fitting  AT2017oz z= 0.055689 zsource= MetaData mwebv= 0.011
# 67 fitting  AT2017po z= 0.031828 zsource= MetaData mwebv= 0.012
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 68 fitting  AT2017wb z= 0.030653 zsource= MetaData mwebv= 0.021
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 69 fitting  AT2017yk z= 0.046439 zsource= MetaData mwebv= 0.03
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# 70 fitting  AT2017zd z= 0.02947 zsource= MetaData mwebv= 0.073
# 71 fitting  ATLAS16agv z= 0.04779 zsource= MetaData mwebv= 0.021
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 72 fitting  ATLAS16bwu z= 0.071803 zsource= MetaData mwebv= 0.019
# 73 fitting  ATLAS16cpu z= 0.018195 zsource= MetaData mwebv= 0.024
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 74 fitting  ATLAS16cxr z= 0.01552 zsource= MetaData mwebv= 0.11
# 75 fitting  ATLAS16dqf z= 0.02117 zsource= MetaData mwebv= 0.06
# 76 fitting  ATLAS17ajn z= 0.028706 zsource= MetaData mwebv= 0.065
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 77 fitting  ATLAS17ajs z= 0.032655 zsource= MetaData mwebv= 0.015
# 78 fitting  ATLAS17axb z= 0.031652 zsource= MetaData mwebv= 0.094
# 79 fitting  ATLAS17bas z= 0.02222 zsource= MetaData mwebv= 0.02
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 80 fitting  CSS160129 z= 0.06766 zsource= MetaData mwebv= 0.032
# 81 fitting  CSS160428 z= 0.03029 zsource= MetaData mwebv= 0.01
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 82 fitting  Gaia16acv z= 0.07772 zsource= MetaData mwebv= 0.01
# 83 fitting  Gaia16agf z= 0.025066 zsource= MetaData mwebv= 0.057
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 84 fitting  Gaia16aki z= 0.073632 zsource= MetaData mwebv= 0.037
# 85 fitting  Gaia16bba z= 0.030458 zsource= MetaData mwebv= 0.04
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 86 fitting  MASTERJ0134 z= 0.044846 zsource= MetaData mwebv= 0.018
# 87 fitting  MASTEROTJ15 z= 0.056436 zsource= MetaData mwebv= 0.024
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 88 fitting  PS15adh z= 0.102757 zsource= MetaData mwebv= 0.026
# 89 fitting  PS15ahs z= 0.025513 zsource= MetaData mwebv= 0.031
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 90 fitting  PS15aii z= 0.046549 zsource= MetaData mwebv= 0.022
# 91 fitting  PS15asb z= 0.04863 zsource= MetaData mwebv= 0.046
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 92 fitting  PS15atx z= 0.071881 zsource= MetaData mwebv= 0.106
# 93 fitting  PS15bbn z= 0.0371 zsource= MetaData mwebv= 0.071
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 94 fitting  PS15bdr z= 0.07096 zsource= MetaData mwebv= 0.014
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 95 fitting  PS15bif z= 0.07937 zsource= MetaData mwebv= 0.061
# 96 fitting  PS15bjg z= 0.068888 zsource= MetaData mwebv= 0.079
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 97 fitting  PS15brr z= 0.051804 zsource= MetaData mwebv= 0.028
# 98 fitting  PS15bsq z= 0.034304 zsource= MetaData mwebv= 0.03
# 99 fitting  PS15bwh z= 0.072671 zsource= MetaData mwebv= 0.025
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 100 fitting  PS15bzz z= 0.08024 zsource= MetaData mwebv= 0.017
# 101 fitting  PS15cfn z= 0.11057 zsource= MetaData mwebv= 0.024
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 102 fitting  PS15cku z= 0.023273 zsource= MetaData mwebv= 0.023
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 103 fitting  PS15cms z= 0.06479 zsource= MetaData mwebv= 0.022
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 104 fitting  PS15coh z= 0.018837 zsource= MetaData mwebv= 0.118
# 105 fitting  PS15cwx z= 0.030065 zsource= MetaData mwebv= 0.149
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 106 fitting  PS15cze z= 0.039371 zsource= MetaData mwebv= 0.185
# 107 fitting  PS15mt z= 0.07085 zsource= MetaData mwebv= 0.021
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 108 fitting  PS16aer z= 0.055467 zsource= MetaData mwebv= 0.02
# 109 fitting  PS16axi z= 0.039299 zsource= MetaData mwebv= 0.034
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 110 fitting  PS16ayd z= 0.053997 zsource= MetaData mwebv= 0.042
# 111 fitting  PS16bby z= 0.053427 zsource= MetaData mwebv= 0.099
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 112 fitting  PS16bnz z= 0.0627 zsource= MetaData mwebv= 0.038
# 113 fitting  PS16ccn z= 0.02431 zsource= MetaData mwebv= 0.058
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 114 fitting  PS16cqa z= 0.043857 zsource= MetaData mwebv= 0.034
# 115 fitting  PS16dnp z= 0.051273 zsource= MetaData mwebv= 0.079
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 116 fitting  PS16el z= 0.047806 zsource= MetaData mwebv= 0.033
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 117 fitting  PS16em z= 0.069815 zsource= MetaData mwebv= 0.037
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 118 fitting  PS16evk z= 0.054468 zsource= MetaData mwebv= 0.061
# 119 fitting  PS16fa z= 0.04611 zsource= MetaData mwebv= 0.022
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 120 fitting  PS16n z= 0.052727 zsource= MetaData mwebv= 0.066
# 121 fitting  PS17akj z= 0.046808 zsource= MetaData mwebv= 0.044
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 122 fitting  PS17bii z= 0.073391 zsource= MetaData mwebv= 0.066
# 123 fitting  PS17tn z= 0.044704 zsource= MetaData mwebv= 0.015
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 124 fitting  PS17yt z= 0.069763 zsource= MetaData mwebv= 0.009
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 125 fitting  PSNJ0107203 z= 0.017005 zsource= MetaData mwebv= 0.06
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 126 fitting  PSNJ0153424 z= 0.025647 zsource= MetaData mwebv= 0.047
# 127 fitting  PSNJ0717457 z= 0.007589 zsource= MetaData mwebv= 0.058
# 128 fitting  PSNJ0859349 z= 0.02812 zsource= MetaData mwebv= 0.021
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 129 fitting  PSNJ1204051 z= 0.043851 zsource= MetaData mwebv= 0.027
# 130 fitting  PSNJ1602512 z= 0.020254 zsource= MetaData mwebv= 0.015
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 131 fitting  PSNJ2043531 z= 0.015497 zsource= MetaData mwebv= 0.086
# 132 fitting  PSNJ2352371 z= 0.026482 zsource= MetaData mwebv= 0.036
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 133 fitting  PTSS-16efw z= 0.035573 zsource= MetaData mwebv= 0.177
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 134 fitting  PTSS17-niq z= 0.06828 zsource= MetaData mwebv= 0.02
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 135 fitting  SN2016aqb z= 0.062894 zsource= MetaData mwebv= 0.032
# 136 fitting  SN2016ayg z= 0.04269 zsource= MetaData mwebv= 0.042
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 137 fitting  SN2016coj z= 0.004523 zsource= MetaData mwebv= 0.016
# 138 fitting  SN2016esh z= 0.044573 zsource= MetaData mwebv= 0.031
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 139 fitting  SN2016gfr z= 0.016693 zsource= MetaData mwebv= 0.115
# 140 fitting  SN2016glp z= 0.08493 zsource= MetaData mwebv= 0.046
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 141 fitting  SN2016glz z= 0.040994 zsource= MetaData mwebv= 0.07
# 142 fitting  SN2016grz z= 0.08748 zsource= MetaData mwebv= 0.043
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 143 fitting  SN2016hhv z= 0.06194 zsource= MetaData mwebv= 0.051
# 144 fitting  SN2016ixf z= 0.06602 zsource= MetaData mwebv= 0.029
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 145 fitting  SN2017cii z= 0.033238 zsource= MetaData mwebv= 0.058
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 146 fitting  SN2017cjv z= 0.059528 zsource= MetaData mwebv= 0.026
# 147 fitting  SN2017ckx z= 0.027158 zsource= MetaData mwebv= 0.029
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 148 fitting  SN2017coa z= 0.04 zsource= MetaData mwebv= 0.056
# 149 fitting  SN2017cpu z= 0.054405 zsource= MetaData mwebv= 0.024
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# 150 fitting  SN2017hn z= 0.02385 zsource= MetaData mwebv= 0.028
# 151 fitting  SN2017jl z= 0.016331 zsource= MetaData mwebv= 0.063
# 152 fitting  SN2017mf z= 0.025612 zsource= MetaData mwebv= 0.009
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(

# %%
res[['x0','x1','c']]
# Out:
#            x0        x1         c
# 0    0.008417 -1.438304  0.063747
# 1    0.002583  0.577431  0.051361
# 2    0.005552 -0.030327  0.024311
# 3    0.006412  2.053063  0.231462
# 4    0.003183 -1.348221  0.015856
# ..        ...       ...       ...
# 148  0.002284  0.882707 -0.019140
# 149  0.002055  0.894776 -0.074217
# 150  0.007760  0.720054 -0.018080
# 151  0.022380  0.655777  0.002265
# 152  0.005493 -0.001862  0.002792
#
# [153 rows x 3 columns]

# %%
# get the column names. We will use them as an input to ensemble.batch()
dfmeta = pd.DataFrame(res.dtypes.to_dict(),index=[0])

# %%
dfmeta
# Out:
#   success  ncall    chisq   ndof        z    z_err       t0   t0_err       x0  \
# 0   int64  int64  float64  int64  float64  float64  float64  float64  float64
#
#     x0_err  ... mwebv_c_cov mwebv_mwebv_cov    Name  Survey ErrorType  \
# 0  float64  ...     float64         float64  object  object    object
#
#   ErrorMesg   bands  bands2 last_fitmjd first_fitmjd
# 0    object  object  object     float64      float64
#
# [1 rows x 60 columns]

# %% [markdown]
# #### Now run with ensemble.batch()

# %%
res = ens.batch(fit_salt2_pp,"SNID","MJD","FLUXCAL","FLUXCALERR","FLT",
          "RA","DEC","REDSHIFT_HELIO","SURVEY2","MWEBV",on=["SNID","RA","DEC","REDSHIFT_HELIO","SURVEY2","MWEBV"],register_bands=True,
          meta=dfmeta,rescols=dfmeta,write_to_file=False,filtmap=filtmap)
# Out:
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# Base model info:
# <Model at 0x1330ab8b0>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  2016W z= 0.019253 zsource= MetaData mwebv= 0.06
# Base model info:
# <Model at 0x1330aa5c0>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  ASASSN-15bc z= 0.036715 zsource= MetaData mwebv= 0.037
# Base model info:
# <Model at 0x133550c10>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  ASASSN-15fs z= 0.02902 zsource= MetaData mwebv= 0.077
# Base model info:
# <Model at 0x133552140>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  ASASSN-15go z= 0.018923 zsource= MetaData mwebv= 0.137
# Base model info:
# <Model at 0x1332a26b0>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  ASASSN-15hg z= 0.029917 zsource= MetaData mwebv= 0.042
# Base model info:
# <Model at 0x1332a13c0>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  ASASSN-15jl z= 0.034682 zsource= MetaData mwebv= 0.014
# Base model info:
# <Model at 0x133550070>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  ASASSN-15kx z= 0.018019 zsource= MetaData mwebv= 0.141
# Base model info:
# <Model at 0x133553220>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  ASASSN-15lg z= 0.020151 zsource= MetaData mwebv= 0.027
# Base model info:
# <Model at 0x13301dc00>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  ASASSN-15mf z= 0.026039 zsource= MetaData mwebv= 0.032
# Base model info:
# <Model at 0x1331aadd0>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  ASASSN-15mg z= 0.042778 zsource= MetaData mwebv= 0.028
# Base model info:
# <Model at 0x133eee800>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  ASASSN-15np z= 0.037683 zsource= MetaData mwebv= 0.026
# Base model info:
# <Model at 0x1335518a0>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  ASASSN-15nq z= 0.03036 zsource= MetaData mwebv= 0.04
# Base model info:
# <Model at 0x133551ea0>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  ASASSN-15nr z= 0.023206 zsource= MetaData mwebv= 0.112
# Base model info:
# <Model at 0x133a5bc10>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  ASASSN-15od z= 0.017603 zsource= MetaData mwebv= 0.026
# Base model info:
# <Model at 0x133a5a440>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  ASASSN-15oh z= 0.016835 zsource= MetaData mwebv= 0.128
# Base model info:
# <Model at 0x1339c6c50>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  ASASSN-15pm z= 0.048784 zsource= MetaData mwebv= 0.028
# Base model info:
# <Model at 0x133a5b010>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  ASASSN-15pn z= 0.038358 zsource= MetaData mwebv= 0.081
# Base model info:
# <Model at 0x1330aaa40>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  ASASSN-15pr z= 0.033093 zsource= MetaData mwebv= 0.029
# Base model info:
# <Model at 0x1339c4310>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  ASASSN-15so z= 0.007022 zsource= MetaData mwebv= 0.013
# Base model info:
# <Model at 0x133a3e6b0>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  ASASSN-15ss z= 0.035558 zsource= MetaData mwebv= 0.199
# Base model info:
# <Model at 0x133384910>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  ASASSN-15tg z= 0.035615 zsource= MetaData mwebv= 0.025
# Base model info:
# <Model at 0x1339b7e20>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  ASASSN-15ti z= 0.01732 zsource= MetaData mwebv= 0.129
# Base model info:
# <Model at 0x1330aa6e0>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  ASASSN-15tz z= 0.022862 zsource= MetaData mwebv= 0.141
# Base model info:
# <Model at 0x1339c6980>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  ASASSN-15uv z= 0.020279 zsource= MetaData mwebv= 0.029
# Base model info:
# <Model at 0x13329d9f0>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  ASASSN-16ad z= 0.016131 zsource= MetaData mwebv= 0.042
# Base model info:
# <Model at 0x133a59630>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  ASASSN-16aj z= 0.030745 zsource= MetaData mwebv= 0.028
# Base model info:
# <Model at 0x133a5add0>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  ASASSN-16ay z= 0.028343 zsource= MetaData mwebv= 0.059
# Base model info:
# <Model at 0x1335784c0>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  ASASSN-16bq z= 0.024935 zsource= MetaData mwebv= 0.033
# Base model info:
# <Model at 0x1332a13f0>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  ASASSN-16br z= 0.02852 zsource= MetaData mwebv= 0.138
# Base model info:
# <Model at 0x133522cb0>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  ASASSN-16ch z= 0.026683 zsource= MetaData mwebv= 0.021
# Base model info:
# <Model at 0x1332a0dc0>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  ASASSN-16cs z= 0.018019 zsource= MetaData mwebv= 0.114
# Base model info:
# <Model at 0x1339c5060>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  ASASSN-16ct z= 0.04191 zsource= MetaData mwebv= 0.046
# Base model info:
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# <Model at 0x1332a2830>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  ASASSN-16db z= 0.034864 zsource= MetaData mwebv= 0.023
# Base model info:
# <Model at 0x133a59600>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  ASASSN-16dn z= 0.01285 zsource= MetaData mwebv= 0.033
# Base model info:
# <Model at 0x1332a1900>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  ASASSN-16dw z= 0.034657 zsource= MetaData mwebv= 0.046
# Base model info:
# <Model at 0x13357bfd0>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  ASASSN-16fo z= 0.0289 zsource= MetaData mwebv= 0.027
# Base model info:
# <Model at 0x1332a17b0>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
# ...
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  PS15cfn z= 0.11057 zsource= MetaData mwebv= 0.024
# Base model info:
# <Model at 0x133a5bf10>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  PS15cku z= 0.023273 zsource= MetaData mwebv= 0.023
# Base model info:
# <Model at 0x13357b1c0>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  PS15cms z= 0.06479 zsource= MetaData mwebv= 0.022
# Base model info:
# <Model at 0x1339c65f0>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  PS15coh z= 0.018837 zsource= MetaData mwebv= 0.118
# Base model info:
# <Model at 0x1339c76a0>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  PS15cwx z= 0.030065 zsource= MetaData mwebv= 0.149
# Base model info:
# <Model at 0x133a5a6b0>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  PS15cze z= 0.039371 zsource= MetaData mwebv= 0.185
# Base model info:
# <Model at 0x1339b4310>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  PS15mt z= 0.07085 zsource= MetaData mwebv= 0.021
# Base model info:
# <Model at 0x1339b75b0>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  PS16aer z= 0.055467 zsource= MetaData mwebv= 0.02
# Base model info:
# <Model at 0x1340040d0>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  PS16axi z= 0.039299 zsource= MetaData mwebv= 0.034
# Base model info:
# <Model at 0x1340057e0>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  PS16ayd z= 0.053997 zsource= MetaData mwebv= 0.042
# Base model info:
# <Model at 0x1339b7820>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  PS16bby z= 0.053427 zsource= MetaData mwebv= 0.099
# Base model info:
# <Model at 0x13329e7a0>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  PS16bnz z= 0.0627 zsource= MetaData mwebv= 0.038
# Base model info:
# <Model at 0x1332a1c00>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  PS16ccn z= 0.02431 zsource= MetaData mwebv= 0.058
# Base model info:
# <Model at 0x1339b46a0>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  PS16cqa z= 0.043857 zsource= MetaData mwebv= 0.034
# Base model info:
# <Model at 0x13329db10>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  PS16dnp z= 0.051273 zsource= MetaData mwebv= 0.079
# Base model info:
# <Model at 0x134007100>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  PS16el z= 0.047806 zsource= MetaData mwebv= 0.033
# Base model info:
# <Model at 0x133eec070>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  PS16em z= 0.069815 zsource= MetaData mwebv= 0.037
# Base model info:
# <Model at 0x133eed600>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  PS16evk z= 0.054468 zsource= MetaData mwebv= 0.061
# Base model info:
# <Model at 0x1330aa650>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  PS16fa z= 0.04611 zsource= MetaData mwebv= 0.022
# Base model info:
# <Model at 0x1330ab010>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  PS16n z= 0.052727 zsource= MetaData mwebv= 0.066
# Base model info:
# <Model at 0x1330ab8b0>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  PS17akj z= 0.046808 zsource= MetaData mwebv= 0.044
# Base model info:
# <Model at 0x133eec280>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  PS17bii z= 0.073391 zsource= MetaData mwebv= 0.066
# Base model info:
# <Model at 0x134776890>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  PS17tn z= 0.044704 zsource= MetaData mwebv= 0.015
# Base model info:
# <Model at 0x133a3e500>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  PS17yt z= 0.069763 zsource= MetaData mwebv= 0.009
# Base model info:
# <Model at 0x1332a1d50>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  PSNJ0107203 z= 0.017005 zsource= MetaData mwebv= 0.06
# Base model info:
# <Model at 0x133eedab0>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  PSNJ0153424 z= 0.025647 zsource= MetaData mwebv= 0.047
# Base model info:
# <Model at 0x1345e8070>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : T23
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# effect (name='mw' frame='obs'):
#   class           : F99Dust
#   wavelength range: [909.09, 60000] Angstroms
#   phase range     : [nan, nan]
# parameters:
#   z     = 0.0
#   t0    = 0.0
#   x0    = 1.0
#   x1    = 0.0
#   c     = 0.0
#   mwebv = 0.0
# 0 fitting  PSNJ0717457 z= 0.007589 zsource= MetaData mwebv= 0.058
# Base model info:
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/sncosmo/fitting.py:187: RuntimeWarning: Dropping following bands from data: Foundation_DR1-PS1-z(out of model wavelength range)
#   warnings.warn("Dropping following bands from data: " +
# /Users/mi/anaconda3/envs/tape_env/lib/python3.10/site-packages/iminuit/util.py:172: IMinuitWarning: Assigned errors must be positive. Non-positive values are replaced by a heuristic.
#   warnings.warn(

# %%
res[['x0','x1','c','bands']]
# Out:
# 0                                                                             x0  \
# SNID        RA         DEC         REDSHIFT_HELIO SURVEY2        MWEBV
# 2016W       37.665487  42.2359685  0.019253       Foundation_DR1 0.060  0.008417
# ASASSN-15bc 61.560987  -8.8856098  0.036715       Foundation_DR1 0.037  0.002583
# ASASSN-15fs 284.669923 43.4688739  0.029020       Foundation_DR1 0.077  0.005552
# ASASSN-15go 92.876886  -16.4841129 0.018923       Foundation_DR1 0.137  0.006412
# ASASSN-15hg 148.452399 9.1938997   0.029917       Foundation_DR1 0.042  0.003183
# ...                                                                          ...
# SN2017coa   132.480332 56.0990451  0.040000       Foundation_DR1 0.056  0.002284
# SN2017cpu   211.968898 9.6420343   0.054405       Foundation_DR1 0.024  0.002055
# SN2017hn    196.914215 6.3376016   0.023850       Foundation_DR1 0.028  0.007760
# SN2017jl    14.382880  30.1852335  0.016331       Foundation_DR1 0.063  0.022380
# SN2017mf    214.129418 39.5863529  0.025612       Foundation_DR1 0.009  0.005493
#
# 0                                                                             x1  \
# SNID        RA         DEC         REDSHIFT_HELIO SURVEY2        MWEBV
# 2016W       37.665487  42.2359685  0.019253       Foundation_DR1 0.060 -1.438304
# ASASSN-15bc 61.560987  -8.8856098  0.036715       Foundation_DR1 0.037  0.577431
# ASASSN-15fs 284.669923 43.4688739  0.029020       Foundation_DR1 0.077 -0.030327
# ASASSN-15go 92.876886  -16.4841129 0.018923       Foundation_DR1 0.137  2.053063
# ASASSN-15hg 148.452399 9.1938997   0.029917       Foundation_DR1 0.042 -1.348221
# ...                                                                          ...
# SN2017coa   132.480332 56.0990451  0.040000       Foundation_DR1 0.056  0.882707
# SN2017cpu   211.968898 9.6420343   0.054405       Foundation_DR1 0.024  0.894776
# SN2017hn    196.914215 6.3376016   0.023850       Foundation_DR1 0.028  0.720054
# SN2017jl    14.382880  30.1852335  0.016331       Foundation_DR1 0.063  0.655777
# SN2017mf    214.129418 39.5863529  0.025612       Foundation_DR1 0.009 -0.001862
#
# 0                                                                              c  \
# SNID        RA         DEC         REDSHIFT_HELIO SURVEY2        MWEBV
# 2016W       37.665487  42.2359685  0.019253       Foundation_DR1 0.060  0.063747
# ASASSN-15bc 61.560987  -8.8856098  0.036715       Foundation_DR1 0.037  0.051361
# ASASSN-15fs 284.669923 43.4688739  0.029020       Foundation_DR1 0.077  0.024311
# ASASSN-15go 92.876886  -16.4841129 0.018923       Foundation_DR1 0.137  0.231462
# ASASSN-15hg 148.452399 9.1938997   0.029917       Foundation_DR1 0.042  0.015856
# ...                                                                          ...
# SN2017coa   132.480332 56.0990451  0.040000       Foundation_DR1 0.056 -0.019140
# SN2017cpu   211.968898 9.6420343   0.054405       Foundation_DR1 0.024 -0.074217
# SN2017hn    196.914215 6.3376016   0.023850       Foundation_DR1 0.028 -0.018080
# SN2017jl    14.382880  30.1852335  0.016331       Foundation_DR1 0.063  0.002265
# SN2017mf    214.129418 39.5863529  0.025612       Foundation_DR1 0.009  0.002792
#
# 0                                                                                      bands
# SNID        RA         DEC         REDSHIFT_HELIO SURVEY2        MWEBV
# 2016W       37.665487  42.2359685  0.019253       Foundation_DR1 0.060  gir
# ASASSN-15bc 61.560987  -8.8856098  0.036715       Foundation_DR1 0.037  girz
# ASASSN-15fs 284.669923 43.4688739  0.029020       Foundation_DR1 0.077  gir
# ASASSN-15go 92.876886  -16.4841129 0.018923       Foundation_DR1 0.137  gir
# ASASSN-15hg 148.452399 9.1938997   0.029917       Foundation_DR1 0.042  gir
# ...                                                                                      ...
# SN2017coa   132.480332 56.0990451  0.040000       Foundation_DR1 0.056  girz
# SN2017cpu   211.968898 9.6420343   0.054405       Foundation_DR1 0.024  girz
# SN2017hn    196.914215 6.3376016   0.023850       Foundation_DR1 0.028  gir
# SN2017jl    14.382880  30.1852335  0.016331       Foundation_DR1 0.063  gir
# SN2017mf    214.129418 39.5863529  0.025612       Foundation_DR1 0.009  gir
#
# [153 rows x 4 columns]
